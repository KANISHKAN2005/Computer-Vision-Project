# %%
import cv2
import numpy as np

# video file
video_path = 'IND.mp4'  
video = cv2.VideoCapture(video_path)

# Template  Dimensions
template = cv2.imread('V.PNG',0)  
w, h = template.shape[::-1]

# Check if the video opened successfully
if not video.isOpened():
    print("Error: Could not open video.")
else:
    # Loop through each frame in the video
    while True:
        ret, frame = video.read()
        
        if not ret:
            break
        
        # Convert the current frame to grayscale
        gray_frame = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
        
        # Apply template matching
        result = cv2.matchTemplate(gray_frame, template, cv2.TM_CCOEFF_NORMED)
        threshold = 0.7
        locations = np.where(result >= threshold)
        
        # Draw rectangles on matched regions
        for pt in zip(*locations[::-1]):
            cv2.rectangle(frame, pt, (pt[0]| + w, pt[1] + h), (0, 255, 255), 2)
        
        # Display the result
        cv2.imshow("Template Matching", frame)
        
        # Break on pressing 'q'
        if cv2.waitKey(79) & 0xFF == ord('q'):
            break
    
    video.release()
    cv2.destroyAllWindows()

# %% [markdown]
# ![RS.png](attachment:abf99fb5-a101-42f4-bb0b-4e62dfbe87bc.png) Templated IMAGE

# %% [markdown]
# # Output

# %% [markdown]
# ![Screenshot 2024-11-12 173116.png](attachment:e1e5a7dc-aa05-423b-87af-f6291dc75829.png)
